# %% [markdown]
# # import the libary

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('D:/DBMS/notes/ML/circket.csv')
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+  \
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %% [markdown]
# # Rename the columns

# %%
df=df.rename(columns={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faces','SR':'Batting_Strike_Rate'})

# %%
df.head(10)
# Out:
#                 Player       Span  Matches  Inns  Not_Outs  Runs
# 0     DG Bradman (AUS)  1928-1948       52    80        10  6996  \
# 1       HC Brook (ENG)  2022-2023       12    20         1  1181
# 2       AC Voges (AUS)  2015-2016       20    31         7  1485
# 3      RG Pollock (SA)  1963-1970       23    41         4  2256
# 4      GA Headley (WI)  1930-1954       22    40         4  2190
# 5    H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 6      E Paynter (ENG)  1931-1939       20    31         5  1540
# 7  KF Barrington (ENG)  1955-1968       82   131        15  6806
# 8       ED Weekes (WI)  1948-1958       48    81         5  4455
# 9     WR Hammond (ENG)  1927-1947       85   140        16  7249
#
#   Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50  0   4s
# 0                334  99.94       9800+                58.60   29  13  7  626  \
# 1                186  62.15        1287                91.76    4   7  1  141
# ...

# %% [markdown]
# # Check the Nulls Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faces             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Player                 0
# Span                   0
# Matches                0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_Inns_Score     0
# Ave                    0
# Balls_Faces            3
# Batting_Strike_Rate    2
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df[df['Balls_Faces'].isna()==1]
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave
# 8        ED Weekes        48    81         5  4455                 207  58.61  \
# 15      CL Walcott        44    74         7  3798                 220  56.68
# 58  Hon.FS Jackson        20    33         4  1415                 144  48.79
#
#     Balls_Faces  Batting_Strike_Rate  100  50  0   4s  6s  Start_Year
# 8          <NA>                  0.0   15  19  6  258   2        1948  \
# 15         <NA>                  0.0   15  14  1  107  11        1948
# 58         <NA>                  0.0    5   6  3   51   0        1893
#
#     End_Year Country
# 8       1958      WI
# 15      1960      WI
# 58      1905     ENG

# %%
df['Balls_Faces']= df['Balls_Faces'].fillna(0)

# %%
df['Batting_Strike_Rate']= df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faces, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Start_Year, End_Year, Country]
# Index: []

# %%
df[df['Player']=='Hon.FS Jackson (ENG)']
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faces, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Start_Year, End_Year, Country]
# Index: []

# %%
df.head(10)
# Out:
#                 Player       Span  Matches  Inns  Not_Outs  Runs
# 0     DG Bradman (AUS)  1928-1948       52    80        10  6996  \
# 1       HC Brook (ENG)  2022-2023       12    20         1  1181
# 2       AC Voges (AUS)  2015-2016       20    31         7  1485
# 3      RG Pollock (SA)  1963-1970       23    41         4  2256
# 4      GA Headley (WI)  1930-1954       22    40         4  2190
# 5    H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 6      E Paynter (ENG)  1931-1939       20    31         5  1540
# 7  KF Barrington (ENG)  1955-1968       82   131        15  6806
# 8       ED Weekes (WI)  1948-1958       48    81         5  4455
# 9     WR Hammond (ENG)  1927-1947       85   140        16  7249
#
#   Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50  0   4s
# 0                334  99.94       9800+                58.60   29  13  7  626  \
# 1                186  62.15        1287                91.76    4   7  1  141
# ...

# %% [markdown]
# # drop the Duplicate

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df[df['Player'].duplicated()==1]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs
# 11      GS Sobers (WI)  1954-1974       93   160        21   8032  \
# 20  KS Williamson (NZ)  2010-2024      100   176        17   8743
# 29  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 38   SM Gavaskar (IND)  1971-1987      125   214        16  10122
#
#    Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50   0
# 11               365*  57.78       4063+                53.58   26  30  12  \
# 20                251  54.98       17006                51.41   32  34  11
# 29                270  52.31       31258                42.51   36  63   8
# 38               236*  51.12      14184+                43.35   34  45  12
#
#       4s  6s
# 11   593  32
# 20   971  24
# 29  1654  21
# 38   908  26

# %%
df[df['Player'].isin(['GS Sobers (WI)','KS Williamson (NZ)','R Dravid (ICC/IND)','SM Gavaskar (IND)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs
# 10      GS Sobers (WI)  1954-1974       93   160        21   8032  \
# 11      GS Sobers (WI)  1954-1974       93   160        21   8032
# 19  KS Williamson (NZ)  2010-2024      100   176        17   8743
# 20  KS Williamson (NZ)  2010-2024      100   176        17   8743
# 28  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 29  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 37   SM Gavaskar (IND)  1971-1987      125   214        16  10122
# 38   SM Gavaskar (IND)  1971-1987      125   214        16  10122
#
#    Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50   0
# 10               365*  57.78       4063+                53.58   26  30  12  \
# 11               365*  57.78       4063+                53.58   26  30  12
# 19                251  54.98       17006                51.41   32  34  11
# ...

# %%
df=df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)','KS Williamson (NZ)','R Dravid (ICC/IND)','SM Gavaskar (IND)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs
# 10      GS Sobers (WI)  1954-1974       93   160        21   8032  \
# 19  KS Williamson (NZ)  2010-2024      100   176        17   8743
# 28  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 37   SM Gavaskar (IND)  1971-1987      125   214        16  10122
#
#    Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50   0
# 10               365*  57.78       4063+                53.58   26  30  12  \
# 19                251  54.98       17006                51.41   32  34  11
# 28                270  52.31       31258                42.51   36  63   8
# 37               236*  51.12      14184+                43.35   34  45  12
#
#       4s  6s
# 10   593  32
# 19   971  24
# 28  1654  21
# 37   908  26

# %% [markdown]
# # split up the spam into start and End

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, Length: 62, dtype: object

# %%
df['Start_Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\GIRISH\AppData\Local\Temp\ipykernel_8284\1236844485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['End_Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\GIRISH\AppData\Local\Temp\ipykernel_8284\3649054782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996  \
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faces  Batting_Strike_Rate  100  50   0
# 0                 334  99.94       9800+                58.60   29  13   7  \
# ...

# %%
df=df.drop(['Span'],axis=1)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score
# 0    DG Bradman (AUS)       52    80        10  6996                334  \
# 1      HC Brook (ENG)       12    20         1  1181                186
# 2      AC Voges (AUS)       20    31         7  1485               269*
# 3     RG Pollock (SA)       23    41         4  2256                274
# 4     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 61   KD Walters (AUS)       74   125        14  5357                250
# 62  GC Smith (ICC/SA)      117   205        13  9265                277
# 63  WH Ponsford (AUS)       29    48         4  2122                266
# 64    SJ McCabe (AUS)       39    62         5  2748                232
# 65   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faces  Batting_Strike_Rate  100  50   0    4s  6s Start_Year
# ...

# %% [markdown]
# # Split the country from the Player

# %%
df['Player'].str.split(pat='(').str[1]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
df['Country']
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Country, Length: 62, dtype: object

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score
# 0    DG Bradman (AUS)       52    80        10  6996                334  \
# 1      HC Brook (ENG)       12    20         1  1181                186
# 2      AC Voges (AUS)       20    31         7  1485               269*
# 3     RG Pollock (SA)       23    41         4  2256                274
# 4     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 61   KD Walters (AUS)       74   125        14  5357                250
# 62  GC Smith (ICC/SA)      117   205        13  9265                277
# 63  WH Ponsford (AUS)       29    48         4  2122                266
# 64    SJ McCabe (AUS)       39    62         5  2748                232
# 65   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faces  Batting_Strike_Rate  100  50   0    4s  6s Start_Year
# ...

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave
# 0    DG Bradman        52    80        10  6996                334  99.94  \
# 1      HC Brook        12    20         1  1181                186  62.15
# 2      AC Voges        20    31         7  1485               269*  61.87
# 3    RG Pollock        23    41         4  2256                274  60.97
# 4    GA Headley        22    40         4  2190               270*  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 61   KD Walters        74   125        14  5357                250  48.26
# 62     GC Smith       117   205        13  9265                277  48.25
# 63  WH Ponsford        29    48         4  2122                266  48.22
# 64    SJ McCabe        39    62         5  2748                232  48.21
# 65   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faces  Batting_Strike_Rate  100  50   0    4s  6s Start_Year
# ...

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave
# 0  DG Bradman        52    80        10  6996                334  99.94  \
# 1    HC Brook        12    20         1  1181                186  62.15
# 2    AC Voges        20    31         7  1485               269*  61.87
# 3  RG Pollock        23    41         4  2256                274  60.97
# 4  GA Headley        22    40         4  2190               270*  60.83
#
#   Balls_Faces  Batting_Strike_Rate  100  50  0   4s  6s Start_Year End_Year
# 0       9800+                58.60   29  13  7  626   6       1928     1948  \
# 1        1287                91.76    4   7  1  141  23       2022     2023
# 2        2667                55.68    5   4  2  186   5       2015     2016
# 3       1707+                54.48    7  11  1  246  11       1963     1970
# 4        416+                56.00   10   5  2  104   1       1930     1954
#
#   Country
# 0     AUS
# 1     ENG
# 2     AUS
# 3      SA
# 4      WI

# %% [markdown]
# # change the datat type

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faces             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].str.split(pat='*').str[0]

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].astype('Int64')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       Int64
# Ave                    float64
# Balls_Faces             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
df['Balls_Faces']=df['Balls_Faces'].str.split(pat='+').str[0]

# %%
df['Balls_Faces']=df['Balls_Faces'].astype('Int64')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       Int64
# Ave                    float64
# Balls_Faces              Int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
df=df.astype({'Start_Year':'int','End_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       Int64
# Ave                    float64
# Balls_Faces              Int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score
# 0         DG Bradman        52    80        10   6996                 334  \
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 5        H Sutcliffe        54    84         9   4555                 194
# 6          E Paynter        20    31         5   1540                 243
# 7      KF Barrington        82   131        15   6806                 256
# 8          ED Weekes        48    81         5   4455                 207
# 9         WR Hammond        85   140        16   7249                 336
# 10         GS Sobers        93   160        21   8032                 365
# 12     KC Sangakkara       134   233        17  12400                 319
# ...

# %%
df['career_length']= df['End_Year']-df['Start_Year']

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave
# 0  DG Bradman        52    80        10  6996                 334  99.94  \
# 1    HC Brook        12    20         1  1181                 186  62.15
# 2    AC Voges        20    31         7  1485                 269  61.87
# 3  RG Pollock        23    41         4  2256                 274  60.97
# 4  GA Headley        22    40         4  2190                 270  60.83
#
#    Balls_Faces  Batting_Strike_Rate  100  50  0   4s  6s  Start_Year
# 0         9800                58.60   29  13  7  626   6        1928  \
# 1         1287                91.76    4   7  1  141  23        2022
# 2         2667                55.68    5   4  2  186   5        2015
# 3         1707                54.48    7  11  1  246  11        1963
# 4          416                56.00   10   5  2  104   1        1930
#
#    End_Year Country  career_length
# 0      1948     AUS             20
# 1      2023     ENG              1
# ...

# %%
# Average Caree Length 

df['career_length'].mean()
# Out:
# 13.193548387096774

# %%
# Avg strike rate who played over 10 years

df[df["career_length"]>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.94681818181819

# %%
# Find the player who palyed before 1960

df[df['Start_Year']<1960]['Player'].count()
# Out:
# 23

# %%
# Max highest Inng Score by Country

df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highest_Inns_Score').reset_index().sort_values('Highest_Inns_Score',ascending=False)
# Out:
#     Country  Highest_Inns_Score
# 5    ICC/WI                 400
# 0       AUS                 380
# 10       SL                 374
# 11       WI                 365
# 1       ENG                 364
# 3   ICC/PAK                 329
# 2   ICC/IND                 319
# 8       PAK                 313
# 9        SA                 278
# 4    ICC/SA                 277
# 6       IND                 254
# 7        NZ                 251
# 12      ZIM                 232

# %%
# hundreds, Fifty, Ducks avg by country

df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.384615  20.846154   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
